# %%
import sys
sys.path.insert(0, '/home/michael/project_khthon/open_street_map')

import re
import pandas as pd
from datetime import datetime
from get_osm_boxes import get_osm_features
from matplotlib import pyplot as plt

# %%
def dms_to_dd(dms):
    pattern = r"(\d+)°(\d+)'([\d.]+)\"([NS])\s*(\d+)°(\d+)'([\d.]+)\"([EW])"
    m = re.match(pattern, dms)
    if not m:
        return None, None
    lat = float(m[1]) + float(m[2])/60 + float(m[3])/3600
    lon = float(m[5]) + float(m[6])/60 + float(m[7])/3600
    if m[4] == 'S': lat = -lat
    if m[8] == 'W': lon = -lon
    return lat, lon

# %%
df = pd.read_excel('/home/michael/project_khthon/grave_inference/AI Grave Dataset.xlsx')
print(f'Loaded {len(df)} graves')
# Out:
# Loaded 50 graves

# %%
import os
import geopandas as gpd

out_dir = '/home/michael/project_khthon/open_street_map/collected_data'
os.makedirs(out_dir, exist_ok=True)

for i, row in df.iterrows():
    lat, lon = dms_to_dd(row['Coordinates'])
    if lat is None:
        print(f"Skipping row {i}: could not parse '{row['Coordinates']}'")
        continue
    print('-' * 50)
    print(f"[{i+1}/{len(df)}] {row['Country']} ({lat:.4f}, {lon:.4f})")

    grave_dir = os.path.join(out_dir, f'grave_{i}')
    os.makedirs(grave_dir, exist_ok=True)

    for year in range(2016, 2027, 2):
        dt = datetime(year, 1, 1)
        try:
            gdf = get_osm_features(lat, lon, 10000, dt=dt)
            gdf['grave_idx'] = i
            gdf['year'] = year
            gdf['lat'] = lat
            gdf['lon'] = lon

            epsg = gdf.crs.to_epsg() if gdf.crs else 4326
            fname = f'{year}_EPSG{epsg}_{lat:.4f}_{lon:.4f}.gpkg'
            path = os.path.join(grave_dir, fname)
            gdf.to_file(path, driver='GPKG')
            print(f"  {year}: {len(gdf)} features -> {fname}")
        except Exception as e:
            print(f"  {year}: ERROR - {e}")

print('\nDone!')
# Out:
# --------------------------------------------------
# [1/50] Sudan (13.6230, 25.3215)
#   2016: 35 features -> 2016_EPSG4326_13.6230_25.3215.gpkg
#   2018: 35 features -> 2018_EPSG4326_13.6230_25.3215.gpkg
#   2020: 35 features -> 2020_EPSG4326_13.6230_25.3215.gpkg
#   2022: 68 features -> 2022_EPSG4326_13.6230_25.3215.gpkg
#   2024: 271 features -> 2024_EPSG4326_13.6230_25.3215.gpkg
#   2026: 378 features -> 2026_EPSG4326_13.6230_25.3215.gpkg
# --------------------------------------------------
# [2/50] Sudan (15.5662, 32.5615)
#   2016: 1001 features -> 2016_EPSG4326_15.5662_32.5615.gpkg
#   2018: 1457 features -> 2018_EPSG4326_15.5662_32.5615.gpkg
#   2020: 2379 features -> 2020_EPSG4326_15.5662_32.5615.gpkg
#   2022: 3489 features -> 2022_EPSG4326_15.5662_32.5615.gpkg
#   2024: 2996 features -> 2024_EPSG4326_15.5662_32.5615.gpkg
#   2026: 3830 features -> 2026_EPSG4326_15.5662_32.5615.gpkg
# --------------------------------------------------
# [3/50] Sudan (15.5686, 32.5618)
#   2024: 267 features -> 2024_EPSG4326_13.6304_25.3327.gpkg
#   2026: 373 features -> 2026_EPSG4326_13.6304_25.3327.gpkg
# --------------------------------------------------
# [11/50] Sudan (14.5160, 32.5126)
#   2016: ERROR - No matching features. Check query location, tags, and log.
#   2018: ERROR - No matching features. Check query location, tags, and log.
#   2020: ERROR - 'building'
#   2022: ERROR - 'building'
#   2024: 34 features -> 2024_EPSG4326_14.5160_32.5126.gpkg
#   2026: 87 features -> 2026_EPSG4326_14.5160_32.5126.gpkg
# --------------------------------------------------
# [12/50] Sudan (13.4592, 25.2962)
#   2016: 2 features -> 2016_EPSG4326_13.4592_25.2962.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 2 features -> 2018_EPSG4326_13.4592_25.2962.gpkg
#   2020: 2 features -> 2020_EPSG4326_13.4592_25.2962.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2022: 2 features -> 2022_EPSG4326_13.4592_25.2962.gpkg
#   2024: 34 features -> 2024_EPSG4326_13.4592_25.2962.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2026: 58 features -> 2026_EPSG4326_13.4592_25.2962.gpkg
# --------------------------------------------------
# [13/50] Sudan (13.4885, 25.2787)
#   2016: 6 features -> 2016_EPSG4326_13.4885_25.2787.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 6 features -> 2018_EPSG4326_13.4885_25.2787.gpkg
#   2020: 6 features -> 2020_EPSG4326_13.4885_25.2787.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2022: 6 features -> 2022_EPSG4326_13.4885_25.2787.gpkg
#   2024: 33 features -> 2024_EPSG4326_13.4885_25.2787.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2026: 57 features -> 2026_EPSG4326_13.4885_25.2787.gpkg
# --------------------------------------------------
# [14/50] Sudan (13.4748, 25.3059)
#   2016: 2 features -> 2016_EPSG4326_13.4748_25.3059.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 2 features -> 2018_EPSG4326_13.4748_25.3059.gpkg
#   2020: 2 features -> 2020_EPSG4326_13.4748_25.3059.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2022: 2 features -> 2022_EPSG4326_13.4748_25.3059.gpkg
#   2024: 33 features -> 2024_EPSG4326_13.4748_25.3059.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2026: 56 features -> 2026_EPSG4326_13.4748_25.3059.gpkg
# --------------------------------------------------
# [15/50] Sudan (13.4672, 25.2887)
#   2016: 2 features -> 2016_EPSG4326_13.4672_25.2887.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 2 features -> 2018_EPSG4326_13.4672_25.2887.gpkg
#   2020: 2 features -> 2020_EPSG4326_13.4672_25.2887.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2022: 2 features -> 2022_EPSG4326_13.4672_25.2887.gpkg
#   2024: 31 features -> 2024_EPSG4326_13.4672_25.2887.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2026: 55 features -> 2026_EPSG4326_13.4672_25.2887.gpkg
# --------------------------------------------------
# [16/50] Sudan (13.5070, 25.2792)
#   2016: 7 features -> 2016_EPSG4326_13.5070_25.2792.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 7 features -> 2018_EPSG4326_13.5070_25.2792.gpkg
#   2020: 7 features -> 2020_EPSG4326_13.5070_25.2792.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2022: 7 features -> 2022_EPSG4326_13.5070_25.2792.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:32: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['feature'] = gdf[target_cols].bfill(axis=1).iloc[:, 0]
#   2024: 58 features -> 2024_EPSG4326_13.5070_25.2792.gpkg
#   2026: 85 features -> 2026_EPSG4326_13.5070_25.2792.gpkg
# --------------------------------------------------
# [17/50] Sudan (13.5055, 25.2966)
#   2016: 7 features -> 2016_EPSG4326_13.5055_25.2966.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018:
#   2024: 270 features -> 2024_EPSG4326_13.6129_25.3385.gpkg
#   2026: 377 features -> 2026_EPSG4326_13.6129_25.3385.gpkg
# --------------------------------------------------
# [32/50] Sudan (12.0097, 24.8354)
#   2016: 24 features -> 2016_EPSG4326_12.0097_24.8354.gpkg
#   2018: 28 features -> 2018_EPSG4326_12.0097_24.8354.gpkg
#   2020: 28 features -> 2020_EPSG4326_12.0097_24.8354.gpkg
#   2022: 35 features -> 2022_EPSG4326_12.0097_24.8354.gpkg
#   2024: 35 features -> 2024_EPSG4326_12.0097_24.8354.gpkg
#   2026: 96 features -> 2026_EPSG4326_12.0097_24.8354.gpkg
# --------------------------------------------------
# [33/50] Sudan (13.1601, 32.6507)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2016: 12 features -> 2016_EPSG4326_13.1601_32.6507.gpkg
#   2018: 31 features -> 2018_EPSG4326_13.1601_32.6507.gpkg
#   2020: 45 features -> 2020_EPSG4326_13.1601_32.6507.gpkg
#   2022: 50 features -> 2022_EPSG4326_13.1601_32.6507.gpkg
#   2024: 88 features -> 2024_EPSG4326_13.1601_32.6507.gpkg
#   2026: 117 features -> 2026_EPSG4326_13.1601_32.6507.gpkg
# --------------------------------------------------
# [34/50] Sudan (11.0106, 29.7188)
#   2016: 10 features -> 2016_EPSG4326_11.0106_29.7188.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 10 features -> 2018_EPSG4326_11.0106_29.7188.gpkg
#   2020: 10 features -> 2020_EPSG4326_11.0106_29.7188.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2022: 10 features -> 2022_EPSG4326_11.0106_29.7188.gpkg
#   2024: 64 features -> 2024_EPSG4326_11.0106_29.7188.gpkg
#   2026: 84 features -> 2026_EPSG4326_11.0106_29.7188.gpkg
# --------------------------------------------------
# [35/50] Sudan (11.0124, 29.7429)
#   2016: 10 features -> 2016_EPSG4326_11.0124_29.7429.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 10 features -> 2018_EPSG4326_11.0124_29.7429.gpkg
#   2020: 10 features -> 2020_EPSG4326_11.0124_29.7429.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2022: 10 features -> 2022_EPSG4326_11.0124_29.7429.gpkg
#   2024: 69 features -> 2024_EPSG4326_11.0124_29.7429.gpkg
#   2026: 97 features -> 2026_EPSG4326_11.0124_29.7429.gpkg
# --------------------------------------------------
# [36/50] Sudan (11.0110, 29.7369)
#   2016: 10 features -> 2016_EPSG4326_11.0110_29.7369.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 10 features -> 2018_EPSG4326_11.0110_29.7369.gpkg
#   2020: 10 features -> 2020_EPSG4326_11.0110_29.7369.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2022: 10 features -> 2022_EPSG4326_11.0110_29.7369.gpkg
#   2024: 69 features -> 2024_EPSG4326_11.0110_29.7369.gpkg
#   2026: 96 features -> 2026_EPSG4326_11.0110_29.7369.gpkg
# --------------------------------------------------
# [37/50] Sudan (13.6822, 22.1385)
#   2016: ERROR - 'building'
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 11 features -> 2018_EPSG4326_13.6822_22.1385.gpkg
#   2020: 14 features -> 2020_EPSG4326_13.6822_22.1385.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2022: 14 features -> 2022_EPSG4326_13.6822_22.1385.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2024: 105 features -> 2024_EPSG4326_13.6822_22.1385.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2026: 427 features -> 2026_EPSG4326_13.6822_22.1385.gpkg
# --------------------------------------------------
# [38/50] Sudan (13.4837, 22.4776)
#   2016: ERROR - 'building'
#   2018: 88 features -> 2018_EPSG4326_13.4837_22.4776.gpkg
#   2020: 88 features -> 2020_EPSG4326_13.4837_22.4776.gpkg
#   2022: 102 features -> 2022_EPSG4326_13.4837_22.4776.gpkg
#   2024: 821 features -> 2024_EPSG4326_13.4837_22.4776.gpkg
#   2026: 963 features -> 2026_EPSG4326_13.4837_22.4776.gpkg
# Skipping row 38: could not parse '13°27′11″ N, 22°26′23″ E'
# --------------------------------------------------
# [40/50] Sudan (13.7134, 25.2785)
#   2016: 32 features -> 2016_EPSG4326_13.7134_25.2785.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
#   2018: 32 features -> 2018_EPSG4326_13.7134_25.2785.gpkg
#   2020: 32 features -> 2020_EPSG4326_13.7134_25.2785.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['building'] = gdf['building'].replace('yes', np.nan)
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:32: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['feature'] = gdf[target_cols].bfill(axis=1).iloc[:, 0]
#   2022: 58 features -> 2022_EPSG4326_13.7134_25.2785.gpkg
#   2024: 57 features -> 2024_EPSG4326_13.7134_25.2785.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:32: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['feature'] = gdf[target_cols].bfill(axis=1).iloc[:, 0]
#   2026: 117 features -> 2026_EPSG4326_13.7134_25.2785.gpkg
# --------------------------------------------------
# [41/50] Sudan (13.6764, 25.3475)
#   2016: 30 features -> 2016_EPSG4326_13.6764_25.3475.gpkg
#   2018: 30 features -> 2018_EPSG4326_13.6764_25.3475.gpkg
#   2020: 30 features -> 2020_EPSG4326_13.6764_25.3475.gpkg
#   2022: 67 features -> 2022_EPSG4326_13.6764_25.3475.gpkg
#   2024: 265 features -> 2024_EPSG4326_13.6764_25.3475.gpkg
#   2026: 368 features -> 2026_EPSG4326_13.6764_25.3475.gpkg
# --------------------------------------------------
# [42/50] Sudan (14.9312, 33.2369)
#   2016: ERROR - 'building'
#   2018: ERROR - 'building'
#   2020: ERROR - 'building'
#   2022: 83 features -> 2022_EPSG4326_14.9312_33.2369.gpkg
#   2024: 142 features -> 2024_EPSG4326_14.9312_33.2369.gpkg
#   2026: 152 features -> 2026_EPSG4326_14.9312_33.2369.gpkg
# --------------------------------------------------
# [43/50] Sudan (13.6343, 25.3458)
#   2016: 31 features -> 2016_EPSG4326_13.6343_25.3458.gpkg
#   2018: 31 features -> 2018_EPSG4326_13.6343_25.3458.gpkg
#   2020: 31 features -> 2020_EPSG4326_13.6343_25.3458.gpkg
#   2022: 64 features -> 2022_EPSG4326_13.6343_25.3458.gpkg
#   2024: 266 features -> 2024_EPSG4326_13.6343_25.3458.gpkg
#   2026: 372 features -> 2026_EPSG4326_13.6343_25.3458.gpkg
# --------------------------------------------------
# [44/50] Sudan (13.6402, 25.3131)
#   2016: 38 features -> 2016_EPSG4326_13.6402_25.3131.gpkg
#   2018: 38 features -> 2018_EPSG4326_13.6402_25.3131.gpkg
#   2020: 38 features -> 2020_EPSG4326_13.6402_25.3131.gpkg
#   2022: 72 features -> 2022_EPSG4326_13.6402_25.3131.gpkg
#   2024: 272 features -> 2024_EPSG4326_13.6402_25.3131.gpkg
#   2026: 378 features -> 2026_EPSG4326_13.6402_25.3131.gpkg
# --------------------------------------------------
# [45/50] Sudan (13.6326, 25.3259)
#   2016: 36 features -> 2016_EPSG4326_13.6326_25.3259.gpkg
#   2018: 36 features -> 2018_EPSG4326_13.6326_25.3259.gpkg
#   2020: 36 features -> 2020_EPSG4326_13.6326_25.3259.gpkg
#   2022: 69 features -> 2022_EPSG4326_13.6326_25.3259.gpkg
#   2024: 268 features -> 2024_EPSG4326_13.6326_25.3259.gpkg
#   2026: 374 features -> 2026_EPSG4326_13.6326_25.3259.gpkg
# --------------------------------------------------
# [46/50] Sudan (13.6115, 25.3163)
#   2016: 35 features -> 2016_EPSG4326_13.6115_25.3163.gpkg
#   2018: 35 features -> 2018_EPSG4326_13.6115_25.3163.gpkg
#   2020: 35 features -> 2020_EPSG4326_13.6115_25.3163.gpkg
#   2022: 68 features -> 2022_EPSG4326_13.6115_25.3163.gpkg
#   2024: 274 features -> 2024_EPSG4326_13.6115_25.3163.gpkg
#   2026: 381 features -> 2026_EPSG4326_13.6115_25.3163.gpkg
# --------------------------------------------------
# [47/50] Sudan (15.0821, 32.9598)
#   2016: ERROR - 'building'
#   2018: ERROR - 'building'
#   2020: 29 features -> 2020_EPSG4326_15.0821_32.9598.gpkg
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:32: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['feature'] = gdf[target_cols].bfill(axis=1).iloc[:, 0]
# /home/michael/project_khthon/open_street_map/get_osm_boxes.py:32: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf['feature'] = gdf[target_cols].bfill(axis=1).iloc[:, 0]
#   2022: 66 features -> 2022_EPSG4326_15.0821_32.9598.gpkg
#   2024: 87 features -> 2024_EPSG4326_15.0821_32.9598.gpkg
#   2026: 129 features -> 2026_EPSG4326_15.0821_32.9598.gpkg
# --------------------------------------------------
# [48/50] Sudan (15.6092, 32.5453)
#   2016: ERROR - Error adding field 'fixme' to layer
#   2018: ERROR - Error adding field 'fixme' to layer
#   2020: ERROR - Error adding field 'fixme' to layer
#   2022: ERROR - Error adding field 'fixme' to layer
#   2024: ERROR - Error adding field 'fixme' to layer

# %%
print(f"Data saved to {out_dir}/")
print(f"Each grave gets a subdirectory: grave_0/, grave_1/, ...")
print(f"Filenames encode year, EPSG, lat, lon: {{year}}_EPSG{{code}}_{{lat}}_{{lon}}.gpkg")

# %%
# %pip install pandas
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# Note: you may need to restart the kernel to use updated packages.
